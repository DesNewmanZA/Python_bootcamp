# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(n=3, random_state=12345)
# Out:
#                                                     App            Category  \
# 6782                      Upgrade for Android DU Master               TOOLS
# 9492                                  Moto File Manager               TOOLS
# 9140  Strava Training: Track Running, Cycling & Swim...  HEALTH_AND_FITNESS
#
#       Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 6782    3.60    12993      5.20   1,000,000  Free     0       Everyone
# 9492    4.10    38655      5.90  10,000,000  Free     0       Everyone
# 9140    4.50   328469      8.80  10,000,000  Free     0           Teen
#
#                 Genres      Last_Updated         Android_Ver
# 6782             Tools   January 9, 2017        2.3.3 and up
# 9492             Tools  February 1, 2018          5.0 and up
# 9140  Health & Fitness    August 1, 2018  Varies with device

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     nan
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     nan
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     nan
# 3                     Command & Conquer: Rivals           FAMILY     nan
# 4                                    CX Network         BUSINESS     nan
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps['Rating'].isna().values.sum()
# Out:
# 1474

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().values.sum()
# Out:
# 476

# %%
df_apps_clean[df_apps_clean['App']=="Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"])
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean = df_apps_clean.sort_values('Rating', ascending=False)
df_apps_clean.head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 1230         Sway Medical      MEDICAL    5.00        3     22.00      100
# 1227    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 1224       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# Just because something is the highest rated doesn't mean it is widely used! It is much easier to get 5/5 with 10 downloads vs 10 million downloads.

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean = df_apps_clean.sort_values('Size_MBs', ascending=False)
df_apps_clean.head()
# Out:
#                                     App Category  Rating  Reviews  Size_MBs  \
# 9945                    Ultimate Tennis   SPORTS    4.30   183004    100.00
# 1795               Navi Radiography Pro  MEDICAL    4.70       11    100.00
# 7927        The Walking Dead: Our World     GAME    4.00    22435    100.00
# 7926                          Post Bank  FINANCE    4.50    60449    100.00
# 8718  Mini Golf King - Multiplayer Game     GAME    4.50   531458    100.00
#
#         Installs  Type   Price Content_Rating   Genres
# 9945  10,000,000  Free       0       Everyone   Sports
# 1795         500  Paid  $15.99       Everyone  Medical
# 7927   1,000,000  Free       0           Teen   Action
# 7926   1,000,000  Free       0       Everyone  Finance
# 8718   5,000,000  Free       0       Everyone   Sports

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean = df_apps_clean.sort_values('Reviews', ascending=False)
df_apps_clean.head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# 10650       Strategy

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
import plotly.express as px

fig = px.pie(df_apps_clean, names='Content_Rating', title="Content ratings", hole=0.6)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="a267f9e6-6417-4ccb-9670-0389419e234f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a267f9e6-6417-4ccb-9670-0389419e234f")) {                    Plotly.newPlot(                        "a267f9e6-6417-4ccb-9670-0389419e234f",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.6, "hovertemplate": "Content_Rating=%{label}<extra></extra>", "labels": ["Teen", "Everyone", "Teen", "Everyone", "Everyone 10+", "Everyone", "Everyone 10+", "Teen", "Everyone", "Everyone 10+", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Mature 17+", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Mature 17+", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Teen", "Mature 17+", "Everyone", "Everyone", "Teen", "Everyone 10+", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Teen", "Everyone", "Teen", "Mature 17+", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Teen", "Everyone", "Everyone 10+", "Teen", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Mature 17+", "Mature 17+", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Mature 17+", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone 10+", "Teen", "Mature 17+", "Everyone", "Mature 17+", "Teen", "Mature 17+", "Everyone", "Everyone", "Mature 17+", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Teen", "Teen", "Teen", "Everyone", "Everyone", "Teen", "Everyone 10+", "Everyone", "Teen", "Everyone 10+", "Teen", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Mature 17+", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Everyone", "Everyone", "Everyone", "Teen", "Teen", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone", "Mature 17+", "Everyone 10+", "Everyone", "Everyone", "Teen", "Teen", "Mature 17+", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Teen", "Everyone", "Everyone", "Teen", "Teen", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Everyone", "Everyone 10+", "Everyone", "Everyone", "Teen", "Everyone", "Everyone", "Mature 17+", "Teen", "Everyone", "Everyone", "Teen", "Ever ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
installs = df_apps_clean.Installs.value_counts().sort_index()
installs.index = installs.index.str.replace(',', '')
installs.index = installs.index.astype(int)
installs = installs.reset_index().sort_values("index")

installs
# Out:
#          index  Installs
# 0            1         3
# 10           5         9
# 4           10        69
# 13          50        56
# 7          100       303
# 16         500       199
# 1         1000       698
# 11        5000       425
# 5        10000       988
# 14       50000       457
# 8       100000      1096
# 17      500000       504
# 2      1000000      1417
# 12     5000000       607
# 6     10000000       933
# 15    50000000       202
# 9    100000000       189
# 18   500000000        24
# 3   1000000000        20

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].str.replace(',', '').astype(int)
df_apps_clean.describe()
# Out:
#         Rating       Reviews  Size_MBs         Installs
# count 8,199.00      8,199.00  8,199.00         8,199.00
# mean      4.17    255,072.97     20.09     9,169,323.86
# std       0.54  1,985,241.40     21.65    58,249,330.53
# min       1.00          1.00      0.01             1.00
# 25%       4.00        126.00      4.90        10,000.00
# 50%       4.30      2,992.00     11.00       100,000.00
# 75%       4.50     43,612.50     28.00     1,000,000.00
# max       5.00 78,158,306.00    100.00 1,000,000,000.00

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].str.replace('$', '').astype(float)
df_apps_clean.describe()
# Out:
#         Rating       Reviews  Size_MBs         Installs    Price
# count 8,199.00      8,199.00  8,199.00         8,199.00 8,199.00
# mean      4.17    255,072.97     20.09     9,169,323.86     1.04
# std       0.54  1,985,241.40     21.65    58,249,330.53    16.85
# min       1.00          1.00      0.01             1.00     0.00
# 25%       4.00        126.00      4.90        10,000.00     0.00
# 50%       4.30      2,992.00     11.00       100,000.00     0.00
# 75%       4.50     43,612.50     28.00     1,000,000.00     0.00
# max       5.00 78,158,306.00    100.00 1,000,000,000.00   400.00

# %%
df_apps_clean[df_apps_clean["Price"]>=250]
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 3897                       I Am Rich     FAMILY    3.60      217      4.90
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 3856                   I am rich VIP  LIFESTYLE    3.80      411      2.60
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2193             I am extremely Rich  LIFESTYLE    2.90       41      2.90
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
#
#       Installs  Type  Price Content_Rating         Genres
# 4606     50000  Paid 399.99       Everyone        Finance
# 3114      5000  Paid 399.99       Everyone        Finance
# 2775      5000  Paid 399.99       Everyone  Entertainment
# 3145      5000  Paid 399.99       Everyone        Finance
# 5765    100000  Paid 399.99       Everyone      Lifestyle
# 1331       100  Paid 399.99       Everyone  Entertainment
# 3897     10000  Paid 389.99       Everyone  Entertainment
# 3554     10000  Paid 399.99       Everyone      Lifestyle
# 3221     10000  Paid 399.99       Everyone  Entertainment
# 3946     10000  Paid 400.00       Everyone      Lifestyle
# 3856     10000  Paid 299.99       Everyone      Lifestyle
# 1946      1000  Paid 399.99           Teen        Finance
# 2394      1000  Paid 399.99       Everyone        Finance
# 2193      1000  Paid 379.99       Everyone      Lifestyle
# 2461      1000  Paid 399.99       Everyone        Finance

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean = df_apps_clean[df_apps_clean["Price"]<250]
df_apps_clean.sort_values("Price", ascending=False, inplace=True)
df_apps_clean.head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 504   AP Art History Flashcards     FAMILY    5.00        1     96.00
#
#       Installs  Type  Price Content_Rating     Genres
# 2281      1000  Paid  79.99       Everyone    Medical
# 1407       100  Paid  39.99       Everyone    Medical
# 2629      1000  Paid  37.99       Everyone  Lifestyle
# 2481      1000  Paid  33.99       Everyone    Medical
# 504         10  Paid  29.99     Mature 17+  Education

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean["Revenue"] = df_apps_clean["Price"]*df_apps_clean["Installs"]
df_apps_clean.sort_values("Revenue", ascending=False, inplace=True)
df_apps_clean.head(15)
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 6746                        Card Wars - Adventure Time           FAMILY
# 7954                                       Bloons TD 5           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 7044                                            Tasker            TOOLS
# 6856                                           Threema    COMMUNICATION
# 4772  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 6406                             NBA JAM by EA SPORTS™           FAMILY
# 6496                             Beautiful Widgets Pro  PERSONALIZATION
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220    4.50  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# 8825    4.60   408292     29.00  10000000  Paid   0.99     Mature 17+
# 7151    4.40   348962     26.00   1000000  Paid   6.99     Mature 17+
# 7977    4.50    23966      0.85   1000000  Paid   5.99       Everyone
# 7477    4.40    49553     48.00   1000000  Paid   5.99       Everyone
# 6594    4.60    87766     12.00   1000000  Paid   4.99       Everyone
# 6082    4.50    76593      4.75    500000  Paid   5.99       Everyone
# 6746    4.30   129603     23.00   1000000  Paid   2.99   Everyone 10+
# 7954    4.60   190086     94.00   1000000  Paid   2.99       Everyone
# 7633    4.60   100805     50.00   1000000  Paid   2.99           Teen
# 7044    4.60    43045      3.40   1000000  Paid   2.99       Everyone
# 6856    4.50    51110      3.50   1000000  Paid   2.99       Everyone
# 4772    4.50     2921     25.00    100000  Paid  24.99       Everyone
# 6406    4.30    56444     43.00    500000  Paid   4.99       Everyone
# 6496    4.20    97890     14.00   1000000  Paid   2.49       Everyone
#
#                          Genres       Revenue
# 9220  Arcade;Action & Adventure 69,900,000.00
# 8825                     Action  9,900,000.00
# 7151                     Action  6,990,000.00
# 7977                  Lifestyle  5,990,000.00
# 7477                Photography  5,990,000.00
# 6594                     Action  4,990,000.00
# 6082                    Weather  2,995,000.00
# 6746    Card;Action & Adventure  2,990,000.00
# 7954                   Strategy  2,990,000.00
# 7633                     Action  2,990,000.00
# 7044                      Tools  2,990,000.00
# 6856              Communication  2,990,000.00
# 4772                    Medical  2,499,000.00
# 6406  Sports;Action & Adventure  2,495,000.00
# 6496            Personalization  2,490,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index,
             y = top10_category.values)
 
bar.show()
# Out:
# <div>                            <div id="65c40595-0465-4e6b-be3d-08ff8fb7408d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65c40595-0465-4e6b-be3d-08ff8fb7408d")) {                    Plotly.newPlot(                        "65c40595-0465-4e6b-be3d-08ff8fb7408d",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["FAMILY", "GAME", "TOOLS", "PRODUCTIVITY", "PERSONALIZATION", "LIFESTYLE", "FINANCE", "MEDICAL", "PHOTOGRAPHY", "BUSINESS"], "xaxis": "x", "y": [1606, 910, 719, 301, 298, 297, 296, 292, 263, 262], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks" ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs

h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <div>                            <div id="33d3add9-8e90-481d-9099-5797abfeb11a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33d3add9-8e90-481d-9099-5797abfeb11a")) {                    Plotly.newPlot(                        "33d3add9-8e90-481d-9099-5797abfeb11a",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [15949410, 26916200, 31116110, 39162676, 44931100, 52083000, 53129800, 97082000, 114233100, 140912410, 211677750, 352852000, 361096500, 455249400, 503267560, 503611120, 692018120, 1096431465, 1134006220, 1400331540, 1532352930, 1665791655, 2113660000, 2369110650, 2894859300, 3916897200, 4437554490, 4649143130, 5487841475, 5788070180, 8099724500, 11039241530, 13858762717], "xaxis": "x", "y": ["EVENTS", "BEAUTY", "PARENTING", "MEDICAL", "COMICS", "LIBRARIES_AND_DEMO", "AUTO_AND_VEHICLES", "HOUSE_AND_HOME", "ART_AND_DESIGN", "DATING", "FOOD_AND_DRINK", "EDUCATION", "WEATHER", "FINANCE", "MAPS_AND_NAVIGATION", "LIFESTYLE", "BUSINESS", "SPORTS", "HEALTH_AND_FITNESS", "SHOPPING", "PERSONALIZATION", "BOOKS_AND_REFERENCE", "ENTERTAINMENT", "NEWS_AND_MAGAZINES", "TRAVEL_AND_LOCAL", "VIDEO_PLAYERS", "FAMILY", "PHOTOGRAPHY", "SOCIAL", "PRODUCTIVITY", "TOOLS", "COMMUNICATION", "GAME"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444 ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
app_installs = df_apps_clean.groupby('Category').agg({'App': pd.Series.count, 'Installs': pd.Series.sum})

# %%
import plotly.express as px

fig = px.scatter(app_installs, 
                 x='App', 
                 y='Installs',
                 title='Category Concentration',
                 size='App',
                 hover_name=app_installs.index,)

fig.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

fig.show()
# Out:
# <div>                            <div id="c9a6d5e3-7942-4a29-a2b2-16f580f94efd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9a6d5e3-7942-4a29-a2b2-16f580f94efd")) {                    Plotly.newPlot(                        "c9a6d5e3-7942-4a29-a2b2-16f580f94efd",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>App=%{marker.size}<br>Installs=%{y}<extra></extra>", "hovertext": ["ART_AND_DESIGN", "AUTO_AND_VEHICLES", "BEAUTY", "BOOKS_AND_REFERENCE", "BUSINESS", "COMICS", "COMMUNICATION", "DATING", "EDUCATION", "ENTERTAINMENT", "EVENTS", "FAMILY", "FINANCE", "FOOD_AND_DRINK", "GAME", "HEALTH_AND_FITNESS", "HOUSE_AND_HOME", "LIBRARIES_AND_DEMO", "LIFESTYLE", "MAPS_AND_NAVIGATION", "MEDICAL", "NEWS_AND_MAGAZINES", "PARENTING", "PERSONALIZATION", "PHOTOGRAPHY", "PRODUCTIVITY", "SHOPPING", "SOCIAL", "SPORTS", "TOOLS", "TRAVEL_AND_LOCAL", "VIDEO_PLAYERS", "WEATHER"], "legendgroup": "", "marker": {"color": "#636efa", "size": [61, 73, 42, 169, 262, 54, 257, 134, 118, 102, 45, 1606, 296, 94, 910, 243, 62, 64, 297, 118, 292, 204, 50, 298, 263, 301, 180, 203, 260, 719, 187, 148, 72], "sizemode": "area", "sizeref": 4.015, "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [61, 73, 42, 169, 262, 54, 257, 134, 118, 102, 45, 1606, 296, 94, 910, 243, 62, 64, 297, 118, 292, 204, 50, 298, 263, 301, 180, 203, 260, 719, 187, 148, 72], "xaxis": "x", "y": [114233100, 53129800, 26916200, 1665791655, 692018120, 44931100, 11039241530, 140912410, 352852000, 2113660000, 15949410, 4437554490, 455249400, 211677750, 13858762717, 1134006220, 97082000, 52083000, 503611120, 503267560, 39162676, 2369110650, 31116110, 1532352930, 4649143130, 5788070180, 1400331540, 5487841475, 1096431465, 8099724500, 2894859300, 3916897200, 361096500], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.77777777 ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean["Genres"].value_counts()
# Out:
# Tools                       718
# Entertainment               467
# Education                   429
# Productivity                301
# Personalization             298
#                            ...
# Lifestyle;Pretend Play        1
# Role Playing;Brain Games      1
# Puzzle;Education              1
# Casual;Music & Video          1
# Strategy;Education            1
# Name: Genres, Length: 114, dtype: int64

# %%
genres_clean = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'Number of genres prior to summarising: {df_apps_clean["Genres"].value_counts().count()}')
num_genres = genres_clean.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# Number of genres prior to summarising: 114
# Number of genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x = num_genres.index[:20], 
             y = num_genres.values[:20],
             title='Top Genres',
             hover_name=num_genres.index[:20],
             color=num_genres.values[:20],
             color_continuous_scale='Agsunset')
 
bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)
 
bar.show()
# Out:
# <div>                            <div id="75828fdc-9e30-4a91-97bc-c7a15d1a570b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75828fdc-9e30-4a91-97bc-c7a15d1a570b")) {                    Plotly.newPlot(                        "75828fdc-9e30-4a91-97bc-c7a15d1a570b",                        [{"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>", "hovertext": ["Tools", "Education", "Entertainment", "Action", "Productivity", "Lifestyle", "Personalization", "Finance", "Medical", "Sports", "Photography", "Business", "Communication", "Health & Fitness", "Casual", "News & Magazines", "Social", "Simulation", "Travel & Local", "Arcade"], "legendgroup": "", "marker": {"color": [719, 587, 498, 304, 301, 298, 298, 296, 292, 270, 263, 262, 258, 245, 216, 204, 203, 200, 187, 185], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Tools", "Education", "Entertainment", "Action", "Productivity", "Lifestyle", "Personalization", "Finance", "Medical", "Sports", "Photography", "Business", "Communication", "Health & Fitness", "Casual", "News & Magazines", "Social", "Simulation", "Travel & Local", "Arcade"], "xaxis": "x", "y": [719, 587, 498, 304, 301, 298, 298, 296, 292, 270, 263, 262, 258, 245, 216, 204, 203, 200, 187, 185], "yaxis": "y"}],                        {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "color"}}, "colorscale": [[0.0, "rgb(75, 41, 145)"], [0.16666666666666666, "rgb(135, 44, 162)"], [0.3333333333333333, "rgb(192, 54, 157)"], [0.5, "rgb(234, 79, 136)"], [0.6666666666666666, "rgb(250, 120, 118)"], [0.8333333333333334, "rgb(246, 169, 122)"], [1.0, "rgb(237, 217, 163)"]], "showscale": false}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "t ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean.Type.value_counts()
# Out:
# Free    7595
# Paid     589
# Name: Type, dtype: int64

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
fig = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')
 
fig.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
 
fig.show()
# Out:
# <div>                            <div id="572b41ad-8896-42d4-a080-b77393c7512c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("572b41ad-8896-42d4-a080-b77393c7512c")) {                    Plotly.newPlot(                        "572b41ad-8896-42d4-a080-b77393c7512c",                        [{"alignmentgroup": "True", "hovertemplate": "Type=Free<br>Category=%{x}<br>App=%{y}<extra></extra>", "legendgroup": "Free", "marker": {"color": "#636efa"}, "name": "Free", "offsetgroup": "Free", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["ART_AND_DESIGN", "AUTO_AND_VEHICLES", "BEAUTY", "BOOKS_AND_REFERENCE", "BUSINESS", "COMICS", "COMMUNICATION", "DATING", "EDUCATION", "ENTERTAINMENT", "EVENTS", "FAMILY", "FINANCE", "FOOD_AND_DRINK", "GAME", "HEALTH_AND_FITNESS", "HOUSE_AND_HOME", "LIBRARIES_AND_DEMO", "LIFESTYLE", "MAPS_AND_NAVIGATION", "MEDICAL", "NEWS_AND_MAGAZINES", "PARENTING", "PERSONALIZATION", "PHOTOGRAPHY", "PRODUCTIVITY", "SHOPPING", "SOCIAL", "SPORTS", "TOOLS", "TRAVEL_AND_LOCAL", "VIDEO_PLAYERS", "WEATHER"], "xaxis": "x", "y": [58, 72, 42, 161, 253, 54, 235, 131, 114, 100, 45, 1456, 289, 92, 834, 232, 62, 64, 284, 113, 229, 202, 48, 233, 248, 283, 178, 201, 238, 656, 179, 144, 65], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Type=Paid<br>Category=%{x}<br>App=%{y}<extra></extra>", "legendgroup": "Paid", "marker": {"color": "#EF553B"}, "name": "Paid", "offsetgroup": "Paid", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["ART_AND_DESIGN", "AUTO_AND_VEHICLES", "BOOKS_AND_REFERENCE", "BUSINESS", "COMMUNICATION", "DATING", "EDUCATION", "ENTERTAINMENT", "FAMILY", "FINANCE", "FOOD_AND_DRINK", "GAME", "HEALTH_AND_FITNESS", "LIFESTYLE", "MAPS_AND_NAVIGATION", "MEDICAL", "NEWS_AND_MAGAZINES", "PARENTING", "PERSONALIZATION", "PHOTOGRAPHY", "PRODUCTIVITY", "SHOPPING", "SOCIAL", "SPORTS", "TOOLS", "TRAVEL_AND_LOCAL", "VIDEO_PLAYERS", "WEATHER"], "xaxis": "x", "y": [3, 1, 8, 9, 22, 3, 4, 2, 150, 7, 2, 76, 11, 13, 5, 63, 2, 2, 65, 15, 18, 2, 2, 22, 63, 8, 4, 7], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "Type"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar":  ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='Downloads for paid apps distributions')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()
# Out:
# <div>                            <div id="6735f621-df7f-4e5a-8b6b-1b158a0abc0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6735f621-df7f-4e5a-8b6b-1b158a0abc0f")) {                    Plotly.newPlot(                        "6735f621-df7f-4e5a-8b6b-1b158a0abc0f",                        [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "Type=%{x}<br>Installs=%{y}<extra></extra>", "legendgroup": "Paid", "marker": {"color": "#636efa"}, "name": "Paid", "notched": true, "offsetgroup": "Paid", "orientation": "v", "showlegend": true, "type": "box", "x": ["Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Paid", "Pai ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

box = px.box(df_paid_apps,
             y='Revenue',
             x='Category',
             title='How much paid apps can earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Revenue estimate',
                  yaxis=dict(type='log'))

box.update_xaxes(categoryorder='min ascending')
    
box.show()
# Out:
# <div>                            <div id="9836a807-3db3-4838-a1f0-127d036921e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9836a807-3db3-4838-a1f0-127d036921e6")) {                    Plotly.newPlot(                        "9836a807-3db3-4838-a1f0-127d036921e6",                        [{"alignmentgroup": "True", "hovertemplate": "Category=%{x}<br>Revenue=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["FAMILY", "GAME", "GAME", "LIFESTYLE", "PHOTOGRAPHY", "GAME", "WEATHER", "FAMILY", "FAMILY", "GAME", "TOOLS", "COMMUNICATION", "MEDICAL", "FAMILY", "PERSONALIZATION", "EDUCATION", "SPORTS", "FAMILY", "SPORTS", "FAMILY", "PHOTOGRAPHY", "FAMILY", "FAMILY", "PRODUCTIVITY", "FAMILY", "PERSONALIZATION", "MAPS_AND_NAVIGATION", "FAMILY", "FAMILY", "GAME", "FAMILY", "FAMILY", "PRODUCTIVITY", "GAME", "GAME", "PERSONALIZATION", "FAMILY", "GAME", "GAME", "GAME", "GAME", "FAMILY", "MEDICAL", "TRAVEL_AND_LOCAL", "SPORTS", "FAMILY", "GAME", "MEDICAL", "PRODUCTIVITY", "GAME", "FAMILY", "GAME", "FAMILY", "GAME", "GAME", "FAMILY", "PERSONALIZATION", "GAME", "ENTERTAINMENT", "FAMILY", "GAME", "BUSINESS", "FAMILY", "PRODUCTIVITY", "BUSINESS", "FAMILY", "PRODUCTIVITY", "TOOLS", "PERSONALIZATION", "WEATHER", "COMMUNICATION", "GAME", "FAMILY", "EDUCATION", "COMMUNICATION", "TOOLS", "WEATHER", "FAMILY", "PHOTOGRAPHY", "HEALTH_AND_FITNESS", "TOOLS", "VIDEO_PLAYERS", "ENTERTAINMENT", "FAMILY", "WEATHER", "GAME", "FAMILY", "GAME", "GAME", "FINANCE", "GAME", "FAMILY", "GAME", "FAMILY", "PERSONALIZATION", "GAME", "FAMILY", "HEALTH_AND_FITNESS", "PHOTOGRAPHY", "FAMILY", "GAME", "FAMILY", "HEALTH_AND_FITNESS", "FAMILY", "GAME", "COMMUNICATION", "MEDICAL", "GAME", "FAMILY", "FOOD_AND_DRINK", "GAME", "FAMILY", "FAMILY", "PARENTING", "TOOLS", "FAMILY", "FAMILY", "SPORTS", "MEDICAL", "FAMILY", "GAME", "GAME", "PERSONALIZATION", "GAME", "FINANCE", "GAME", "GAME", "FAMILY", "FAMILY", "FAMILY", "FAMILY", "MEDICAL", "FAMILY", "TOOLS", "TOOLS", "PRODUCTIVITY", "FAMILY", "HEALTH_AND_FITNESS", "FAMILY", "FAMILY", "FAMILY", "PHOTOGRAPHY", "FAMILY", "TRAVEL_AND_LOCAL", "PERSONALIZATION", "MEDICAL", "MEDICAL", "PERSONALIZATION", "MEDICAL", "FAMILY", "PHOTOGRAPHY", "GAME", "AUTO_AND_VEHICLES", "HEALTH_AND_FITNESS", "GAME", "HEALTH_AND_FITNESS", "FAMILY", "GAME", "PERSONALIZATION", "FAMILY", "FAMILY", "MEDICAL", "GAME", "MEDICAL", "LIFESTYLE", "MEDICAL", "TOOLS", "PRODUCTIVITY", "MEDICAL", "HEALTH_AND_FITNESS", "TRAVEL_AND_LOCAL", "MEDICAL", "FAMILY", "GAME", "SPORTS", "FAMILY", "TOOLS", "FAMILY", "COMMUNICATION", "GAME", "GAME", "PHOTOGRAPHY", "FAMILY", "GAME", "PERSONALIZATION", "FAMILY", "GAME", "BOOKS_AND_REFERENCE", "FAMILY", "FAMILY", "GAME", "FAMILY", "DATING", "FAMILY", "MEDICAL", "HEALTH_AND_FITNESS", "FAMILY", "FAMILY", "TOOLS", "LIFESTYLE", "PERSONALIZATION", "GAME", "FOOD_AND_DRINK", "MEDICAL", "TOOLS", "MEDICAL", "MEDICAL", "FAMILY", "MEDICAL", "WEATHER", "GAME", "TOOLS", "FAMILY", "GAME", "SHOPPING", "FAMILY", "TOOLS", "FAMILY", "FINANCE", "FAMILY", "FAMILY", "BUSINESS", "PERSONALIZATION", "MAPS_AND_NAVIGATION", "MEDICAL", "TOOLS", "MEDICAL", "FAMILY", "FAMILY", "FAMILY", "COMMUNICATION", "TOOLS", "FAMILY", "COMMUNICATION", "FAMILY", "MEDICAL", "TOOLS", "TOOLS", "TOOLS", "TOOLS", "FAMILY", "TOOLS", "FAMILY", "TOOLS", "TOOLS", "COMMUNICATION", "TOOLS", "FAMILY", "TOOLS", "LIFESTYLE", "FAMILY", "BOOKS_AND_REFERENCE", "FAMILY", "PHOTOGRAPHY", "MEDICAL", "MEDICAL", "TRAVEL_AND_LOCAL", "MEDICAL", "MEDICAL", "LIFESTYLE", "PRODUCTIVITY", "MEDICAL", "FAMILY", "MEDICAL", "TOOLS", "VIDEO_PLAYERS", "PERSONALIZATION", "TOOLS", "FAMILY", "TOOLS", "PHOTOGRAPHY", "TOOLS", "FAMILY", "MEDICAL", "PERSONALI ...
